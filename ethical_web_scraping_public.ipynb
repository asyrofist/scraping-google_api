# %% [markdown]
# # Ethical Web Scraping - Using Google API
# ### By Guang Yi Chua, Marketing Analyst, Construct Digital

# %% [markdown]
# This code was written quickly in conjunction with my blog post to demonstrate the power of using web scraping to get useful and relevant information about your customers, which will allow you to segment them more efficiently, thus allowing higher ROI.
#
# Remember, always make sure you identify yourself and respect the robots.txt file of every website.
#
# Happy scraping!

# %%
# Last ran on June 7th, 2018 with Python Version 2.7.15
# Import the necessary packages for CustomSearch to work
# These packages can be installed through 'conda install' or 'pip install'

from googleapiclient.discovery import build
import pprint
import pandas as pd

# %%
# This is just sample code for how to identify yourself if no API is available
# The following are most of the packages you would use if this were the case

import requests
import urllib2 
from bs4 import BeautifulSoup

identity = {'user-agent' : 'Safari/11.1.1 (Macintosh; Intel Mac OS X 10_13_5); \
             Your Name Here/Your Company/email@yourcompany.com'}

html = requests.get(url, headers=identity)

# %% [markdown]
# In order to use Google's API, you need to have:
#
# 1. A Google Cloud account
# 2. A Google Cloud SDK (along with Python) installed
# 3. An application created in the Console
# 4. Set up a Custom Search Engine
#
# More detailed instructions can be found at: https://stackoverflow.com/questions/37083058/programmatically-searching-google-in-python-using-custom-search

# %% [markdown]
# #### People Search

# %%
# These can be found on your Cloud Console and Custom Search Engine dashboard, respectively
my_api_key = "Your API Key here"
my_cse_id = "Your Customer Search Engine Here"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

# Search for names here. In lieu of a list, you can try reading in a list of
# names with an Excel or CSV file with Pandas
search_parameters = ["Guang Yi Chua", "Edwin Tam"]
results = []

# The free version of Google API limits you to 100 queries per day
# If you require more, it is $5 per additional 1,000 queries
for names in search_parameters :
    results.append(google_search(names, my_api_key, my_cse_id, num=10))

# %%
# The JSON that the search gives is added on to a dictionary. 
# The first entry is the name that you searched
# The second number gives the individual hits from Google
results[0][0].keys()
# Out:
# [u'kind',
#  u'title',
#  u'displayLink',
#  u'htmlTitle',
#  u'formattedUrl',
#  u'htmlFormattedUrl',
#  u'pagemap',
#  u'snippet',
#  u'htmlSnippet',
#  u'link']

# %%
# Results are returned in JSON format 

for result in results:
    pprint.pprint(result)
# Out:
# [{u'displayLink': u'www.linkedin.com',
#   u'formattedUrl': u'https://www.linkedin.com/in/guangyic',
#   u'htmlFormattedUrl': u'https://www.linkedin.com/in/<b>guangyi</b>c',
#   u'htmlSnippet': u'Se <b>Guang Yi</b> Chuas profil p\xe5 LinkedIn \u2013 verdens st\xf8rste faglige netv\xe6rk. Guang <br>\nYis erfaring inkluderer General Assembly, Music and Ballet Company og United&nbsp;...',
#   u'htmlTitle': u'<b>Guang Yi Chua</b> | Faglig profil',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.linkedin.com/in/guangyic',
#   u'pagemap': {u'cse_image': [{u'src': u'https://media.licdn.com/mpr/mpr/shrink_100_100/p/8/005/092/188/23e56c2.jpg'}],
#                u'cse_thumbnail': [{u'height': u'100',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQMYNdJLSf_-hvXd9gx8x__rL5kxU9w15jYFVmMScuIizM65MKfe1_g',
#                                    u'width': u'100'}],
#                u'hcard': [{u'fn': u'Guang Yi Chua',
#                            u'photo': u'https://media.licdn.com/mpr/mpr/shrinknp_200_200/p/8/005/02c/3a0/1bcdac3.jpg',
#                            u'title': u'Aspiring Data Scientist'}],
#                u'metatags': [{u'apphost': u'null',
#                               u'appinstance': u'null',
#                               u'application-name': u'LinkedIn',
#                               u'appname': u'chrome',
#                               u'appversion': u'null',
#                               u'detectadblock': u'//platform.linkedin.com/js/px.js',
#                               u'globaltrackingappid': u'webTracking',
#                               u'globaltrackingappname': u'chrome',
#                               u'globaltrackingurl': u'//www.linkedin.com/mob/tracking',
#                               u'lnkd-track-json-lib': u'https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv',
#                               u'msapplication-tilecolor': u'#0077B5',
#                               u'msapplication-tileimage': u'https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png',
#                               u'og:description': u'Se Guang Yi Chuas professionel profil p\xe5 LinkedIn. LinkedIn er verdens st\xf8rste erhvervsnetv\xe6rk, der hj\xe6lper fagfolk som Guang Yi Chua med at finde interne kontakter, der kan anbefale jobkandidater, brancheeksperter og forretningspartnere.',
#                               u'og:image': u'https://media.licdn.com/mpr/mpr/shrinknp_200_200/p/8/005/02c/3a0/1bcdac3.jpg',
#                               u'og:title': u'Guang Yi Chua | Faglig profil | LinkedIn',
#                               u'og:url': u'https://dk.linkedin.com/in/guangyic?trk=public_profile_card_url',
#                               u'pageimpressionid': u'25a9bdc7-5c86-44bd-ab90-12c86d29b984',
#                               u'pagekey': u'public_profile_v3_desktop',
#                               u'referrer': u'origin',
#                               u'remotenavjscontentbaseurl': u'https://static.licdn.com/scds/concat/common/js?v=0.1.378',
#                               u'treeid': u'8vMmrBFI7RRAM7ZchCsAAA==',
#                               u'twitter:card': u'summary',
#                               u'twitter:site': u'@LinkedIn'}],
#                u'person': [{u'location': u'Singapore',
#                             u'org': u'General Assembly',
#                             u'role': u'Aspiring Data Scientist'}]},
#   u'snippet': u'Se Guang Yi Chuas profil p\xe5 LinkedIn \u2013 verdens st\xf8rste faglige netv\xe6rk. Guang \nYis erfaring inkluderer General Assembly, Music and Ballet Company og United\xa0...',
#   u'title': u'Guang Yi Chua | Faglig profil'},
#  {u'cacheId': u'jWflGk2QqiAJ',
#   u'displayLink': u'www.urmc.rochester.edu',
#   u'formattedUrl': u'https://www.urmc.rochester.edu/labs/carney/personnel/alumni.aspx',
#   u'htmlFormattedUrl': u'https://www.urmc.rochester.edu/labs/carney/personnel/alumni.aspx',
#   u'htmlSnippet': u'Undergraduate Student. Jesse Checkla Jesse H. Checkla Undergraduate <br>\nStudent. <b>Guang Yi Chua</b> Undergraduate Student. Kyle Critelli Undergraduate <br>\nStudent.',
#   u'htmlTitle': u'Lab Alumni - Carney Lab - University of Rochester Medical Center',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.urmc.rochester.edu/labs/carney/personnel/alumni.aspx',
#   u'pagemap': {u'cse_image': [{u'src': u'https://www.urmc.rochester.edu/neuroscience/_shared/img/postDocs/KennethHenry.jpg'}],
#                u'cse_thumbnail': [{u'height': u'150',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQxz3AOCduBV3bvIOQZp0G_bqME7kvOneUMS1FYuKYrYPOT0IPJIWLhIg',
#                                    u'width': u'100'}],
#                u'metatags': [{u'viewport': u'width=device-width, initial-scale=1'}]},
#   u'snippet': u'Undergraduate Student. Jesse Checkla Jesse H. Checkla Undergraduate \nStudent. Guang Yi Chua Undergraduate Student. Kyle Critelli Undergraduate \nStudent.',
#   u'title': u'Lab Alumni - Carney Lab - University of Rochester Medical Center'},
#  {u'displayLink': u'iopscience.iop.org',
#   u'fileFormat': u'PDF/Adobe Acrobat',
#   u'formattedUrl': u'iopscience.iop.org/article/10.1209/0295-5075/113/10005/pdf',
#   u'htmlFormattedUrl': u'iopscience.iop.org/article/10.1209/0295-5075/113/10005/pdf',
#   u'htmlSnippet': u'Jan 2, 2016 <b>...</b> Oscillator. Wang <b>Guang</b>-<b>Yi</b>, He Jie-Ling, Yuan Fang et al. ... Abstract \u2013 Two <br>\ninteresting properties of <b>Chua&#39;s</b> circuits are presented. First, two-&nbsp;...',
#   u'htmlTitle': u'2D bifurcations and Newtonian properties of memristive <b>Chua&#39;s</b> circuits',
#   u'kind': u'customsearch#result',
#   u'link': u'http://iopscience.iop.org/article/10.1209/0295-5075/113/10005/pdf',
#   u'mime': u'application/pdf',
#   u'pagemap': {u'metatags': [{u'creationdate': u"D:20160125081521+05'30'",
#                               u'moddate': u"D:20180416070511+01'00'",
#                               u'producer': u'Acrobat Distiller 9.0.0 (Windows); modified using iText\xae 5.5.10 \xa92000-2015 iText Group NV (AGPL-version)',
#                               u'title': u'untitled'}]},
#   u'snippet': u"Jan 2, 2016 ... Oscillator. Wang Guang-Yi, He Jie-Ling, Yuan Fang et al. ... Abstract \u2013 Two \ninteresting properties of Chua's circuits are presented. First, two-\xa0...",
#   u'title': u"2D bifurcations and Newtonian properties of memristive Chua's circuits"},
#  {u'displayLink': u'www.worldscientific.com',
#   u'formattedUrl': u'https://www.worldscientific.com/doi/abs/10.1142/S0218127412501337',
#   u'htmlFormattedUrl': u'https://www.worldscientific.com/doi/abs/10.1142/S0218127412501337',
#   u'htmlSnippet': u'Bocheng Bao, Tao Jiang, <b>Guangyi</b> Wang, Peipei Jin, Han Bao, Mo Chen. (2017) <br>\nTwo-memristor-based <b>Chua</b>?s hyperchaotic circuit with plane equilibrium and&nbsp;...',
#   u'htmlTitle': u'hyperchaos in a memristor-based modified canonical <b>chua&#39;s</b> circuit',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.worldscientific.com/doi/abs/10.1142/S0218127412501337',
#   u'pagemap': {u'cse_image': [{u'src': u'https://www.worldscientific.com/na101/home/literatum/publisher/wspc/journals/covergifs/ijbc/cover.gif'}],
#                u'cse_thumbnail': [{u'height': u'250',
#                                    u'src': u'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRcKtUlko1pE8zym-hTFIRp-Nv62ONzXv8tTypI2BuVKhgn7RKUYQwYIC_F',
#                                    u'width': u'190'}],
#                u'metatags': [{u'baidu-site-verification': u'9ADzHFSSYY',
#                               u'citation_journal_title': u'International Journal of Bifurcation and Chaos',
#                               u'dc.coverage': u'world',
#                               u'dc.creator': u'ANDREW L.  FITCH',
#                               u'dc.date': u'2012-07-16',
#                               u'dc.description': u"After the successful solid state implementation of the memristor, memristor-based circuits have received a lot of attention. In this paper, a memristor with cubic nonlinear characteristics is employed in the modified canonical Chua's circuit. A systematic study of hyperchaotic behavior in this circuit is performed with the help of nonlinear tools such as Lyapunov exponents, phase portraits and bifurcation diagrams. In particular, an imitative memristor circuit is examined to reveal the construction of hyperchaotic attractors.",
#                               u'dc.format': u'text/HTML',
#                               u'dc.identifier': u'10.1142/S0218127412501337',
#                               u'dc.language': u'en',
#                               u'dc.publisher': u'World Scientific Publishing Company',
#                               u'dc.source': u'http://dx.doi.org/10.1142/S0218127412501337',
#                               u'dc.subject': u"Chua's circuit; hyperchaos; Lyapunov exponents; memristor; nonlinear circuit",
#                               u'dc.title': u"HYPERCHAOS IN A MEMRISTOR-BASED MODIFIED CANONICAL CHUA'S CIRCUIT",
#                               u'dc.type': u'research-article',
#                               u'og:description': u'ANDREW L. FITCH et al, Int. J. Bifurcation Chaos 22, 1250133 (2012) [8 pages] https://doi.org/10.1142/S0218127412501337',
#                               u'og:image': u'https://www.worldscientific.com/na101/home/literatum/publisher/wspc/journals/covergifs/ijbc/cover.gif',
#                               u'og:site_name': u'World Scientific Publishing Company',
#                               u'og:title': u"HYPERCHAOS IN A MEMRISTOR-BASED MODIFIED CANONICAL CHUA'S CIRCUIT",
#                               u'og:type': u'article',
#                               u'og:url': u'https://www.worldscientific.com/doi/abs/10.1142/S0218127412501337'}],
#                u'scholarlyarticle': [{u'copyrightyear': u'2012',
#                                       u'volume': u'22'}]},
#   u'snippet': u'Bocheng Bao, Tao Jiang, Guangyi Wang, Peipei Jin, Han Bao, Mo Chen. (2017) \nTwo-memristor-based Chua?s hyperchaotic circuit with plane equilibrium and\xa0...',
#   u'title': u"hyperchaos in a memristor-based modified canonical chua's circuit"},
#  {u'cacheId': u'yVV7pJ5HcvkJ',
#   u'displayLink': u'www.pas.rochester.edu',
#   u'formattedUrl': u'www.pas.rochester.edu/~manly/class/P102_2011S/',
#   u'htmlFormattedUrl': u'www.pas.rochester.edu/~manly/class/P102_2011S/',
#   u'htmlSnippet': u'Recitation leaders: Scott Lucchini, slucchin@u.rochester.edu. <b>Guang Yi Chua</b>, <br>\n<b>guang</b>.<b>yi</b>.<b>chua</b>@rochester.edu. Adam Lanman, adam.lanman@rochester.edu.',
#   u'htmlTitle': u'Link to class website',
#   u'kind': u'customsearch#result',
#   u'link': u'http://www.pas.rochester.edu/~manly/class/P102_2011S/',
#   u'pagemap': {u'cse_image': [{u'src': u'http://www.pas.rochester.edu/~manly/class/P102_2011S/Andromeda.jpg'}],
#                u'cse_thumbnail': [{u'height': u'201',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQqHj6WC-wK-HcZzwoNxMCGvvPqLfYNukdlbIMTyjntxwoAtyVq1k73DGz2',
#                                    u'width': u'251'}]},
#   u'snippet': u'Recitation leaders: Scott Lucchini, slucchin@u.rochester.edu. Guang Yi Chua, \nguang.yi.chua@rochester.edu. Adam Lanman, adam.lanman@rochester.edu.',
#   u'title': u'Link to class website'},
#  {u'displayLink': u'aip.scitation.org',
#   u'formattedUrl': u'https://aip.scitation.org/doi/abs/10.1063/1.4958296',
#   u'htmlFormattedUrl': u'https://aip.scitation.org/doi/abs/10.1063/1.4958296',
#   u'htmlSnippet': u'Fang Yuan<sup>1, a)</sup>, <b>Guangyi</b> Wang1, b),c), and Xiaowei Wang<sup>2, c)</sup> ... M. Itoh and <br>\nL. O. <b>Chua</b>, \u201c Memristor oscillators,\u201d Int. J. Bifurcation Chaos 18, 3183\u20133206 (<br>\n2008).',
#   u'htmlTitle': u'Extreme multistability in a memristor-based multi-scroll hyper ...',
#   u'kind': u'customsearch#result',
#   u'link': u'https://aip.scitation.org/doi/abs/10.1063/1.4958296',
#   u'pagemap': {u'cse_image': [{u'src': u'https://aip.scitation.org/na101/home/literatum/publisher/aip/journals/content/cha/2016/cha.2016.26.issue-7/1.4958296/production/images/medium/1.4958296.figures.f1.gif'}],
#                u'metatags': [{u'article:author': u'Fang Yuan',
#                               u'article:published_time': u'201607',
#                               u'citation_abstract': u'In this paper, a new memristor-based multi-scroll hyper-chaotic system is designed. The proposed memristor-based system possesses multiple complex dynamic behaviors compared with other chaotic systems. Various coexisting attractors and hidden coexisting attractors are observed in this system, which means extreme multistability arises. Besides, by adjusting parameters of the system, this chaotic system can perform single-scroll attractors, double-scroll attractors, and four-scroll attractors. Basic dynamic characteristics of the system are investigated, including equilibrium points and stability, bifurcation diagrams, Lyapunov exponents, and so on. In addition, the presented system is also realized by an analog circuit to confirm the correction of the numerical simulations.',
#                               u'citation_abstract_html_url': u'https://aip.scitation.org/doi/abs/10.1063/1.4958296',
#                               u'citation_author': u'Fang Yuan',
#                               u'citation_doi': u'10.1063/1.4958296',
#                               u'citation_firstpage': u'073107',
#                               u'citation_issn': u'1054-1500',
#                               u'citation_issue': u'7',
#                               u'citation_journal_title': u'Chaos: An Interdisciplinary Journal of Nonlinear Science',
#                               u'citation_keywords': u'bifurcation, chaos, Lyapunov methods, memristors, numerical analysis',
#                               u'citation_online_date': u'2016-07',
#                               u'citation_pdf_url': u'https://aip.scitation.org/doi/pdf/10.1063/1.4958296',
#                               u'citation_publication_date': u'2016-07-13',
#                               u'citation_publisher': u'AIP Publishing LLC',
#                               u'citation_title': u'Extreme multistability in a memristor-based multi-scroll hyper-chaotic system',
#                               u'citation_volume': u'26',
#                               u'dc.coverage': u'world',
#                               u'dc.creator': u'Fang Yuan',
#                               u'dc.date': u'2016-07-13',
#                               u'dc.date.issued': u'2016-07-13',
#                               u'dc.description': u'In this paper, a new memristor-based multi-scroll hyper-chaotic system is designed. The proposed memristor-based system possesses multiple complex dynamic behaviors compared with other chaotic systems. Various coexisting attractors and hidden coexisting attractors are observed in this system, which means extreme multistability arises. Besides, by adjusting parameters of the system, this chaotic system can perform single-scroll attractors, double-scroll attractors, and four-scroll attractors. Basic dynamic characteristics of the system are investigated, including equilibrium points and stability, bifurcation diagrams, Lyapunov exponents, and so on. In addition, the presented system is also realized by an analog circuit to confirm the correction of the numerical simulations.',
#                               u'dc.format': u'text/HTML',
#                               u'dc.identifier': u'10.1063/1.4958296',
#                               u'dc.language': u'en',
#                               u'dc.publisher': u'AIP Publishing LLC',
#                               u'dc.subject': u'bifurcation; chaos; Lyapunov methods; memristors; numerical analysis',
#                               u'dc.title': u'Extreme multistability in a memristor-based multi-scroll hyper-chaotic system',
#                               u'dc.type': u'research-article',
#                               u'og:description': u'In this paper, a new memristor-based multi-scroll hyper-chaotic system is designed. The proposed memristor-based system possesses multiple complex dynamic behaviors compared with other chaotic systems. Various coexisting attractors and hidden coexisting attractors are observed in this system, which means extreme multistability arises. Besides, by adjusting parameters of the system, this chaotic system can perform single-scroll attractors, double-scroll attractors, and four-scroll attractors. Basic dynamic characteristics of the system are investigated, including equilibrium points and stability, bifurcation diagrams, Lyapunov exponents, and so on. In addition, the presented system is also realized by an analog circuit to confirm the correction of the numerical simulations.',
#                               u'og:image': u'https://aip.scitation.org/na101/home/literatum/publisher/aip/journals/content/cha/2016/cha.2016.26.issue-7/1.4958296/production/images/medium/1.4958296.figures.f1.gif',
#                               u'og:image:type': u'image/gif',
#                               u'og:site_name': u'AIP Publishing',
#                               u'og:title': u'Extreme multistability in a memristor-based multi-scroll hyper-chaotic system',
#                               u'og:type': u'article',
#                               u'og:url': u'https://aip.scitation.org/doi/10.1063/1.4958296',
#                               u'pbcontext': u';journal:journal:cha;page:string:Article/Chapter View;subPage:string:Abstract;website:website:aip-site;issue:issue:10.1063/cha.2016.26.issue-7;article:article:10.1063/1.4958296;wgroup:string:Publication Websites;pageGroup:string:Publication Pages',
#                               u'twitter:description': u'In this paper, a new memristor-based multi-scroll hyper-chaotic system is designed. The proposed memristor-based system possesses multiple complex dynamic behaviors compared with other chaotic systems. Various coexisting attractors and hidden coexisting attractors are observed in this system, which means extreme multistability arises. Besides, by adjusting parameters of the system, this chaotic system can perform single-scroll attractors, double-scroll attractors, and four-scroll attractors. Basic dynamic characteristics of the system are investigated, including equilibrium points and stability, bifurcation diagrams, Lyapunov exponents, and so on. In addition, the presented system is also realized by an analog circuit to confirm the correction of the numerical simulations.',
#                               u'twitter:image:alt': u'Extreme multistability in a memristor-based multi-scroll hyper-chaotic system',
#                               u'twitter:site': u'@AIPPublishing',
#                               u'twitter:title': u'Extreme multistability in a memristor-based multi-scroll hyper-chaotic system'}]},
#   u'snippet': u'Fang Yuan1, a), Guangyi Wang1, b),c), and Xiaowei Wang2, c) ... M. Itoh and \nL. O. Chua, \u201c Memristor oscillators,\u201d Int. J. Bifurcation Chaos 18, 3183\u20133206 (\n2008).',
#   u'title': u'Extreme multistability in a memristor-based multi-scroll hyper ...'},
#  {u'cacheId': u'6qXTIFnmv2EJ',
#   u'displayLink': u'www.youtube.com',
#   u'formattedUrl': u'https://www.youtube.com/watch?v=sjIMeFggPv4',
#   u'htmlFormattedUrl': u'https://www.youtube.com/watch?v=sjIMeFggPv4',
#   u'htmlSnippet': u'Jan 28, 2014 <b>...</b> How I Met Your Mother S9 X 16: The Singing English Muffin (Sung by The Mother<br>\n, Cristin Milioti) (HD). <b>Guang Yi Chua</b>. Loading... Unsubscribe&nbsp;...',
#   u'htmlTitle': u'How I Met Your Mother S9 X 16: The Singing English Muffin (Sung ...',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.youtube.com/watch?v=sjIMeFggPv4',
#   u'pagemap': {u'cse_image': [{u'src': u'https://i.ytimg.com/vi/sjIMeFggPv4/maxresdefault.jpg'}],
#                u'cse_thumbnail': [{u'height': u'168',
#                                    u'src': u'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRYRhk6ai3v2cdIXR80O-_x4pi9MMtEHsBbgfp9SSOlSCIA5_NF7xZHBsEv',
#                                    u'width': u'300'}],
#                u'imageobject': [{u'height': u'720',
#                                  u'url': u'https://i.ytimg.com/vi/sjIMeFggPv4/maxresdefault.jpg',
#                                  u'width': u'1280'}],
#                u'metatags': [{u'al:android:app_name': u'YouTube',
#                               u'al:android:package': u'com.google.android.youtube',
#                               u'al:android:url': u'vnd.youtube://www.youtube.com/watch?v=sjIMeFggPv4&feature=applinks',
#                               u'al:ios:app_name': u'YouTube',
#                               u'al:ios:app_store_id': u'544007664',
#                               u'al:ios:url': u'vnd.youtube://www.youtube.com/watch?v=sjIMeFggPv4&feature=applinks',
#                               u'al:web:url': u'https://www.youtube.com/watch?v=sjIMeFggPv4&feature=applinks',
#                               u'fb:app_id': u'87741124305',
#                               u'og:description': u'The most adorable clip of a muffin singing a song. Sung by Cristin Milioti, of course. Watch How I Met Your Mother on Mondays at 8/7c. Only CBS To watch the ...',
#                               u'og:image': u'https://i.ytimg.com/vi/sjIMeFggPv4/maxresdefault.jpg',
#                               u'og:site_name': u'YouTube',
#                               u'og:title': u'How I Met Your Mother S9 X 16: The Singing English Muffin (Sung by The Mother, Cristin Milioti) (HD)',
#                               u'og:type': u'video.other',
#                               u'og:url': u'https://www.youtube.com/watch?v=sjIMeFggPv4',
#                               u'og:video:height': u'720',
#                               u'og:video:secure_url': u'https://www.youtube.com/embed/sjIMeFggPv4',
#                               u'og:video:tag': u'Cristin Milioti (Theater Actor)',
#                               u'og:video:type': u'text/html',
#                               u'og:video:url': u'https://www.youtube.com/embed/sjIMeFggPv4',
#                               u'og:video:width': u'1280',
#                               u'theme-color': u'#ff0000',
#                               u'title': u'How I Met Your Mother S9 X 16: The Singing English Muffin (Sung by The Mother, Cristin Milioti) (HD)',
#                               u'twitter:app:id:googleplay': u'com.google.android.youtube',
#                               u'twitter:app:id:ipad': u'544007664',
#                               u'twitter:app:id:iphone': u'544007664',
#                               u'twitter:app:name:googleplay': u'YouTube',
#                               u'twitter:app:name:ipad': u'YouTube',
#                               u'twitter:app:name:iphone': u'YouTube',
#                               u'twitter:app:url:googleplay': u'https://www.youtube.com/watch?v=sjIMeFggPv4',
#                               u'twitter:app:url:ipad': u'vnd.youtube://www.youtube.com/watch?v=sjIMeFggPv4&feature=applinks',
#                               u'twitter:app:url:iphone': u'vnd.youtube://www.youtube.com/watch?v=sjIMeFggPv4&feature=applinks',
#                               u'twitter:card': u'player',
#                               u'twitter:description': u'The most adorable clip of a muffin singing a song. Sung by Cristin Milioti, of course. Watch How I Met Your Mother on Mondays at 8/7c. Only CBS To watch the ...',
#                               u'twitter:image': u'https://i.ytimg.com/vi/sjIMeFggPv4/maxresdefault.jpg',
#                               u'twitter:player': u'https://www.youtube.com/embed/sjIMeFggPv4',
#                               u'twitter:player:height': u'720',
#                               u'twitter:player:width': u'1280',
#                               u'twitter:site': u'@youtube',
#                               u'twitter:title': u'How I Met Your Mother S9 X 16: The Singing English Muffin (Sung by The Mother, Cristin Milioti) (HD)',
#                               u'twitter:url': u'https://www.youtube.com/watch?v=sjIMeFggPv4'}],
#                u'person': [{u'url': u'http://www.youtube.com/user/archangel1806'},
#                            {u'url': u'https://plus.google.com/116668890781955801727'}],
#                u'videoobject': [{u'channelid': u'UC7FaQl_bVu3obvEp46p7FAA',
#                                  u'datepublished': u'2014-01-28',
#                                  u'description': u'The most adorable clip of a muffin singing a song. Sung by Cristin Milioti, of course. Watch How I Met Your Mother on Mondays at 8/7c. Only CBS To watch the ...',
#                                  u'duration': u'PT0M14S',
#                                  u'embedurl': u'https://www.youtube.com/embed/sjIMeFggPv4',
#                                  u'genre': u'Entertainment',
#                                  u'height': u'720',
#                                  u'interactioncount': u'135666',
#                                  u'isfamilyfriendly': u'True',
#                                  u'name': u'How I Met Your Mother S9 X 16: The Singing English Muffin (Sung by The Mother, Cristin Milioti) (HD)',
#                                  u'paid': u'False',
#                                  u'playertype': u'HTML5 Flash',
#                                  u'regionsallowed': u'AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH...',
#                                  u'thumbnailurl': u'https://i.ytimg.com/vi/sjIMeFggPv4/maxresdefault.jpg',
#                                  u'unlisted': u'False',
#                                  u'url': u'https://www.youtube.com/watch?v=sjIMeFggPv4',
#                                  u'videoid': u'sjIMeFggPv4',
#                                  u'width': u'1280'}]},
#   u'snippet': u'Jan 28, 2014 ... How I Met Your Mother S9 X 16: The Singing English Muffin (Sung by The Mother\n, Cristin Milioti) (HD). Guang Yi Chua. Loading... Unsubscribe\xa0...',
#   u'title': u'How I Met Your Mother S9 X 16: The Singing English Muffin (Sung ...'},
#  {u'cacheId': u'jvyC98HJIqQJ',
#   u'displayLink': u'www.eng.nus.edu.sg',
#   u'fileFormat': u'Microsoft Excel',
#   u'formattedUrl': u'www.eng.nus.edu.sg/cee/programmes/.../Mentor_Mentee_CVE.xlsx',
#   u'htmlFormattedUrl': u'www.eng.nus.edu.sg/cee/programmes/.../Mentor_Mentee_CVE.xlsx',
#   u'htmlSnippet': u'10, CVE1, ANIQ HILMAN B NASDIAN, Prof David <b>Chua</b> Kim Huat. 11, 10, CVE1 <br>\n... 40, 39, CVE1, FU MIN <b>YI</b>, Dr <b>Kuang</b> Sze Chian, Kevin. 41, 40, CVE1, FU YING<br>\n&nbsp;...',
#   u'htmlTitle': u'List of Students&#39; Mentors',
#   u'kind': u'customsearch#result',
#   u'link': u'http://www.eng.nus.edu.sg/cee/programmes/BEng_ce/Mentor_Mentee_CVE.xlsx',
#   u'mime': u'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#   u'pagemap': {u'metatags': [{u'application version': u'15.0300',
#                               u'author': u'Sarimah Bte Mustafa',
#                               u'creation date': u'1/9/2018 02:11:14',
#                               u'last saved by': u'Sarimah Bte Mustafa',
#                               u'last saved date': u'1/12/2018 01:55:35',
#                               u'links dirty': u'no',
#                               u'links up to date': u'no',
#                               u'scale crop': u'no',
#                               u'security': u'0',
#                               u'shared doc': u'no',
#                               u'source': u'Microsoft Excel'}]},
#   u'snippet': u'10, CVE1, ANIQ HILMAN B NASDIAN, Prof David Chua Kim Huat. 11, 10, CVE1 \n... 40, 39, CVE1, FU MIN YI, Dr Kuang Sze Chian, Kevin. 41, 40, CVE1, FU YING\n\xa0...',
#   u'title': u"List of Students' Mentors"},
#  {u'cacheId': u'gpOocn7-0gAJ',
#   u'displayLink': u'www.eng.nus.edu.sg',
#   u'fileFormat': u'PDF/Adobe Acrobat',
#   u'formattedUrl': u'https://www.eng.nus.edu.sg/.../AY1617-Deans-List-awardees-for-Sem-2.pdf',
#   u'htmlFormattedUrl': u'https://www.eng.nus.edu.sg/.../AY1617-Deans-List-awardees-for-Sem-2.pdf',
#   u'htmlSnippet': u'4 <b>CHUA</b> XIN MIN AMANDA. BIE. 5 DONG THI ANH KHUE. BIE ... CHE. 41 ARIEL <br>\n<b>CHUA</b> YI HUI. CHE. Page 1 of 7 ... 109 WEE <b>GUANG YI</b>. CVE. 110 WEE POH&nbsp;...',
#   u'htmlTitle': u'Semester 2',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.eng.nus.edu.sg/wp-content/uploads/AY1617-Deans-List-awardees-for-Sem-2.pdf',
#   u'mime': u'application/pdf',
#   u'pagemap': {u'metatags': [{u'author': u'Chen Weiting',
#                               u'creationdate': u"D:20170717121032+08'00'",
#                               u'creator': u'Microsoft\xae Excel\xae 2013',
#                               u'moddate': u"D:20170717121032+08'00'",
#                               u'producer': u'Microsoft\xae Excel\xae 2013'}]},
#   u'snippet': u'4 CHUA XIN MIN AMANDA. BIE. 5 DONG THI ANH KHUE. BIE ... CHE. 41 ARIEL \nCHUA YI HUI. CHE. Page 1 of 7 ... 109 WEE GUANG YI. CVE. 110 WEE POH\xa0...',
#   u'title': u'Semester 2'},
#  {u'cacheId': u'vp7TlKEUGtkJ',
#   u'displayLink': u'www.tandfonline.com',
#   u'formattedUrl': u'www.tandfonline.com/doi/abs/10.1080/21642583.2013.879842',
#   u'htmlFormattedUrl': u'www.tandfonline.com/doi/abs/10.1080/21642583.2013.879842',
#   u'htmlSnippet': u'By replacing <b>Chua&#39;s</b> diode with the active flux-controlled TiO 2 memristor, a <br>\nchaotic circuit is obtained. By means of the conventional dynamic analysis <br>\nmethod,&nbsp;...',
#   u'htmlTitle': u'Research on a chaotic circuit based on an active TiO 2 memristor ...',
#   u'kind': u'customsearch#result',
#   u'link': u'http://www.tandfonline.com/doi/abs/10.1080/21642583.2013.879842',
#   u'pagemap': {u'cse_image': [{u'src': u'https://badges.altmetric.com/?size=240&score=1&types=tttttttt'}],
#                u'cse_thumbnail': [{u'height': u'225',
#                                    u'src': u'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTYsJcCnW8FqpPT4qbdXu4tb7RO7hf4fxRJZiiOqvhTGDtaNv6Wc8wT2DA',
#                                    u'width': u'225'}],
#                u'metatags': [{u'citation_journal_title': u'Systems Science & Control Engineering: An Open Access Journal',
#                               u'dc.coverage': u'world',
#                               u'dc.creator': u'Wei Wang',
#                               u'dc.date': u'16 Dec 2014',
#                               u'dc.description': u"The memristor is the fourth fundamental circuit element besides the resistor, inductor and capacitor. As a two-terminal nonlinear resistor, the memristor has a broad application prospect. In this paper, a negative memconductance expression of a flux-controlled memristor is derived from the relationship between voltage and current for the Hewlett-Packard memristor. By replacing Chua's diode with the active flux-controlled TiO 2 memristor, a chaotic circuit is obtained. By means of the conventional dynamic analysis method, dynamic behaviors of the chaotic circuit are investigated. Software simulation and theoretical analysis all indicate that this active memristor-based chaotic circuit has more complex behaviors. Furthermore, the integrated circuit experiment on the digital signal processor chip of this circuit was also realized.",
#                               u'dc.format': u'text/HTML',
#                               u'dc.identifier': u'879842',
#                               u'dc.language': u'en',
#                               u'dc.publisher': u'Taylor & Francis',
#                               u'dc.source': u'http://mc.manuscriptcentral.com/tssc',
#                               u'dc.subject': u"TiO 2 memristor; Chua's oscillator; chaotic system; dynamic analysis",
#                               u'dc.title': u'Research on a chaotic circuit based on an active TiO 2 memristor',
#                               u'dc.type': u'research-article',
#                               u'og:description': u'(2014). Research on a chaotic circuit based on an active TiO 2 memristor. Systems Science & Control Engineering: Vol. 2, No. 1, pp. 740-744.',
#                               u'og:image': u'http://www.tandfonline.com/na101/home/literatum/publisher/tandf/journals/content/tssc20/2014/tssc20.v002.i01/tssc20.v002.i01/20140217-01/tssc20.v002.i01.cover.jpg',
#                               u'og:site_name': u'Taylor & Francis',
#                               u'og:title': u'Research on a chaotic circuit based on an active TiO 2 memristor',
#                               u'og:type': u'article',
#                               u'og:url': u'http://www.tandfonline.com/doi/abs/10.1080/21642583.2013.879842',
#                               u'pbcontext': u';journal:journal:tssc20;issue:issue:10.1080/tssc20.v002.i01;page:string:Article/Chapter View;subPage:string:Abstract;wgroup:string:Publication Websites;website:website:TFOPB;pageGroup:string:Publication Pages;article:article:10.1080/21642583.2013.879842',
#                               u'twitter:card': u'summary_large_image',
#                               u'twitter:site': u'@tandfonline',
#                               u'viewport': u'width=device-width,initial-scale=1,maximum-scale=1, user-scalable=0'}]},
#   u'snippet': u"By replacing Chua's diode with the active flux-controlled TiO 2 memristor, a \nchaotic circuit is obtained. By means of the conventional dynamic analysis \nmethod,\xa0...",
#   u'title': u'Research on a chaotic circuit based on an active TiO 2 memristor ...'}]
# [{u'cacheId': u'Y7LbtrU_PK8J',
#   u'displayLink': u'www.uwindsor.ca',
#   u'formattedUrl': u'www.uwindsor.ca/engineering/civil/56/dr-edwin-tam',
#   u'htmlFormattedUrl': u'www.uwindsor.ca/engineering/civil/56/dr-<b>edwin</b>-<b>tam</b>',
#   u'htmlSnippet': u'Dr. <b>Edwin Tam</b>. Associate Professor Cross appointed to Mechanical Engineering <br>\n519-253-3000 ext. 2561 edwintam@uwindsor.ca. Office: 3075 CEI. Education.',
#   u'htmlTitle': u'Dr. <b>Edwin Tam</b> | Civil and Environmental Engineering',
#   u'kind': u'customsearch#result',
#   u'link': u'http://www.uwindsor.ca/engineering/civil/56/dr-edwin-tam',
#   u'pagemap': {u'Document': [{u'encoded': u'Associate Professor Cross appointed to Mechanical Engineering 519-253-3000 ext. 2561 edwintam@uwindsor.ca Office: 3075 CEI Education PhD Civil Engineering, University of Toronto MSc Civil Engineeri...',
#                               u'label': u'Faculty',
#                               u'num_replies': u'0',
#                               u'title': u'Dr. Edwin Tam'}],
#                u'cse_image': [{u'src': u'http://www.uwindsor.ca/engineering/civil/sites/uwindsor.ca.engineering.civil/files/edwin_tam_cei.jpg'}],
#                u'cse_thumbnail': [{u'height': u'251',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQt__AgVqJBv3AD67gLKFAI2zwYHzezqqhymPQE2ElqZ2aroR6dlKDBMWI',
#                                    u'width': u'201'}],
#                u'metatags': [{u'og:author': u'anneb',
#                               u'og:description': u'Associate Professor Cross appointed to Mechanical Engineering 519-253-3000 ext.',
#                               u'og:image': u'http://drupal7.dev:80/sites/all/themes/uwindsor_admin/logo.png',
#                               u'og:site_name': u'Civil and Environmental Engineering',
#                               u'og:title': u'Dr. Edwin Tam',
#                               u'og:type': u'website',
#                               u'og:url': u'http://www.uwindsor.ca/engineering/civil/56/dr-edwin-tam',
#                               u'theme-color': u'#ffffff',
#                               u'viewport': u'width=device-width, initial-scale=1.0'}]},
#   u'snippet': u'Dr. Edwin Tam. Associate Professor Cross appointed to Mechanical Engineering \n519-253-3000 ext. 2561 edwintam@uwindsor.ca. Office: 3075 CEI. Education.',
#   u'title': u'Dr. Edwin Tam | Civil and Environmental Engineering'},
#  {u'cacheId': u'nFxFjXlqPoIJ',
#   u'displayLink': u'www.youtube.com',
#   u'formattedUrl': u'https://www.youtube.com/watch?v=e41m_EQcD98',
#   u'htmlFormattedUrl': u'https://www.youtube.com/watch?v=e41m_EQcD98',
#   u'htmlSnippet': u'Nov 26, 2014 <b>...</b> This talk was given at a local TEDx event, produced independently of the TED <br>\nConferences. One year after I was born, in 1970, the average US&nbsp;...',
#   u'htmlTitle': u'Trash talk | Dr. <b>Edwin Tam</b> | TEDxUniversityofWindsor - YouTube',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.youtube.com/watch?v=e41m_EQcD98',
#   u'pagemap': {u'cse_image': [{u'src': u'https://i.ytimg.com/vi/e41m_EQcD98/maxresdefault.jpg'}],
#                u'cse_thumbnail': [{u'height': u'168',
#                                    u'src': u'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDhr6gy0oo0mEzQpw0Xo2Ilo5oU0Xik0uL1vJKPz5TyKjZggiHvx0ZRQ-h',
#                                    u'width': u'300'}],
#                u'imageobject': [{u'height': u'720',
#                                  u'url': u'https://i.ytimg.com/vi/e41m_EQcD98/maxresdefault.jpg',
#                                  u'width': u'1280'}],
#                u'metatags': [{u'al:android:app_name': u'YouTube',
#                               u'al:android:package': u'com.google.android.youtube',
#                               u'al:android:url': u'vnd.youtube://www.youtube.com/watch?v=e41m_EQcD98&feature=applinks',
#                               u'al:ios:app_name': u'YouTube',
#                               u'al:ios:app_store_id': u'544007664',
#                               u'al:ios:url': u'vnd.youtube://www.youtube.com/watch?v=e41m_EQcD98&feature=applinks',
#                               u'al:web:url': u'https://www.youtube.com/watch?v=e41m_EQcD98&feature=applinks',
#                               u'fb:app_id': u'87741124305',
#                               u'og:description': u'This talk was given at a local TEDx event, produced independently of the TED Conferences. One year after I was born, in 1970, the average US citizen produced...',
#                               u'og:image': u'https://i.ytimg.com/vi/e41m_EQcD98/maxresdefault.jpg',
#                               u'og:site_name': u'YouTube',
#                               u'og:title': u'Trash talk | Dr. Edwin Tam | TEDxUniversityofWindsor',
#                               u'og:type': u'video.other',
#                               u'og:url': u'https://www.youtube.com/watch?v=e41m_EQcD98',
#                               u'og:video:height': u'720',
#                               u'og:video:secure_url': u'https://www.youtube.com/embed/e41m_EQcD98',
#                               u'og:video:tag': u'ted talk',
#                               u'og:video:type': u'text/html',
#                               u'og:video:url': u'https://www.youtube.com/embed/e41m_EQcD98',
#                               u'og:video:width': u'1280',
#                               u'theme-color': u'#ff0000',
#                               u'title': u'Trash talk | Dr. Edwin Tam | TEDxUniversityofWindsor',
#                               u'twitter:app:id:ipad': u'544007664',
#                               u'twitter:app:id:iphone': u'544007664',
#                               u'twitter:app:name:ipad': u'YouTube',
#                               u'twitter:app:name:iphone': u'YouTube',
#                               u'twitter:app:url:iphone': u'vnd.youtube://www.youtube.com/watch?v=e41m_EQcD98&feature=applinks',
#                               u'twitter:card': u'player',
#                               u'twitter:description': u'This talk was given at a local TEDx event, produced independently of the TED Conferences. One year after I was born, in 1970, the average US citizen produced...',
#                               u'twitter:image': u'https://i.ytimg.com/vi/e41m_EQcD98/maxresdefault.jpg',
#                               u'twitter:site': u'@youtube',
#                               u'twitter:title': u'Trash talk | Dr. Edwin Tam | TEDxUniversityofWindsor',
#                               u'twitter:url': u'https://www.youtube.com/watch?v=e41m_EQcD98'}],
#                u'person': [{u'url': u'http://www.youtube.com/user/TEDxTalks'},
#                            {u'url': u'https://plus.google.com/118095909811519284948'}],
#                u'videoobject': [{u'channelid': u'UCsT0YIqwnpJCM-mx7-gSA4Q',
#                                  u'datepublished': u'2014-11-26',
#                                  u'description': u'This talk was given at a local TEDx event, produced independently of the TED Conferences. One year after I was born, in 1970, the average US citizen produced...',
#                                  u'duration': u'PT15M27S',
#                                  u'embedurl': u'https://www.youtube.com/embed/e41m_EQcD98',
#                                  u'genre': u'Nonprofits & Activism',
#                                  u'height': u'720',
#                                  u'interactioncount': u'708',
#                                  u'isfamilyfriendly': u'True',
#                                  u'name': u'Trash talk | Dr. Edwin Tam | TEDxUniversityofWindsor',
#                                  u'paid': u'False',
#                                  u'playertype': u'HTML5 Flash',
#                                  u'regionsallowed': u'AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH...',
#                                  u'thumbnailurl': u'https://i.ytimg.com/vi/e41m_EQcD98/maxresdefault.jpg',
#                                  u'unlisted': u'False',
#                                  u'url': u'https://www.youtube.com/watch?v=e41m_EQcD98',
#                                  u'videoid': u'e41m_EQcD98',
#                                  u'width': u'1280'}]},
#   u'snippet': u'Nov 26, 2014 ... This talk was given at a local TEDx event, produced independently of the TED \nConferences. One year after I was born, in 1970, the average US\xa0...',
#   u'title': u'Trash talk | Dr. Edwin Tam | TEDxUniversityofWindsor - YouTube'},
#  {u'cacheId': u'hW0Eh1zq5c4J',
#   u'displayLink': u'psychiatry.ubc.ca',
#   u'formattedUrl': u'https://psychiatry.ubc.ca/person/edwin-tam/',
#   u'htmlFormattedUrl': u'https://psychiatry.ubc.ca/person/<b>edwin</b>-<b>tam</b>/',
#   u'htmlSnippet': u'Edwin TamMood &amp; Anxiety Disorders Program. ... Vancouver, V6T2A1. 604\u2013822<br>\n\u20137342. <b>edwin</b>.<b>tam</b>@ubc.ca. Program members: Mood &amp; Anxiety Disorders&nbsp;...',
#   u'htmlTitle': u'<b>Edwin Tam</b> | Department of Psychiatry',
#   u'kind': u'customsearch#result',
#   u'link': u'https://psychiatry.ubc.ca/person/edwin-tam/',
#   u'pagemap': {u'cse_image': [{u'src': u'https://psychiatry.ubc.ca/files/2012/07/default_user_icon_128.png'}],
#                u'cse_thumbnail': [{u'height': u'100',
#                                    u'src': u'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcR8pyi94jFe-7C9tQZ0OYbZmA94HhvNo8jwWk10mmAmTJFcmWb5EOSw',
#                                    u'width': u'100'}],
#                u'metatags': [{u'template': u'UBC Collab 1.0.2',
#                               u'viewport': u'width=device-width'}]},
#   u'snippet': u'Edwin TamMood & Anxiety Disorders Program. ... Vancouver, V6T2A1. 604\u2013822\n\u20137342. edwin.tam@ubc.ca. Program members: Mood & Anxiety Disorders\xa0...',
#   u'title': u'Edwin Tam | Department of Psychiatry'},
#  {u'displayLink': u'www.linkedin.com',
#   u'formattedUrl': u'https://www.linkedin.com/in/edwin-tam-6b653a2',
#   u'htmlFormattedUrl': u'https://www.linkedin.com/in/<b>edwin</b>-<b>tam</b>-6b653a2',
#   u'htmlSnippet': u'View <b>Edwin Tam&#39;s</b> professional profile on LinkedIn. LinkedIn is the world&#39;s largest <br>\nbusiness network, helping professionals like <b>Edwin Tam</b> discover inside&nbsp;...',
#   u'htmlTitle': u'<b>Edwin Tam</b> | LinkedIn',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.linkedin.com/in/edwin-tam-6b653a2',
#   u'pagemap': {u'cse_image': [{u'src': u'https://media.licdn.com/dms/image/C5603AQGKifc0vzSIAA/profile-displayphoto-shrink_200_200/0?e=1528696800&v=beta&t=9MHkhb3JV2LtlFF5y6x8qNNyMyDQaDAZA-RV_b7RGE4'}],
#                u'hcard': [{u'fn': u'Edwin Tam'}],
#                u'metatags': [{u'apphost': u'public-profile-frontend',
#                               u'appinstance': u'i001',
#                               u'application-name': u'LinkedIn',
#                               u'appname': u'chrome',
#                               u'appversion': u'0.1.433',
#                               u'detectadblock': u'//platform.linkedin.com/js/px.js',
#                               u'globaltrackingappid': u'webTracking',
#                               u'globaltrackingappname': u'chrome',
#                               u'globaltrackingurl': u'//www.linkedin.com/mob/tracking',
#                               u'lnkd-track-json-lib': u'https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv',
#                               u'msapplication-tilecolor': u'#0077B5',
#                               u'msapplication-tileimage': u'https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png',
#                               u'og:description': u"View Edwin Tam\u2019s professional profile on LinkedIn. LinkedIn is the world's largest business network, helping professionals like Edwin Tam discover inside connections to recommended job candidates, industry experts, and business partners.",
#                               u'og:image': u'https://media.licdn.com/dms/image/C5603AQGKifc0vzSIAA/profile-displayphoto-shrink_200_200/0?e=1528696800&v=beta&t=9MHkhb3JV2LtlFF5y6x8qNNyMyDQaDAZA-RV_b7RGE4',
#                               u'og:title': u'Edwin Tam | LinkedIn',
#                               u'og:url': u'https://www.linkedin.com/in/edwin-tam-6b653a2?trk=public_profile_card_url',
#                               u'pageimpressionid': u'206c562e-38a2-42a8-a7ab-7f1952bb6e4a',
#                               u'pagekey': u'public_profile_v3_desktop',
#                               u'referrer': u'origin',
#                               u'remotenavjscontentbaseurl': u'https://static.licdn.com/scds/concat/common/js?v=0.1.508',
#                               u'treeid': u'bFKsT++ZJBUgZNyu8CoAAA==',
#                               u'twitter:card': u'summary',
#                               u'twitter:site': u'@LinkedIn'}]},
#   u'snippet': u"View Edwin Tam's professional profile on LinkedIn. LinkedIn is the world's largest \nbusiness network, helping professionals like Edwin Tam discover inside\xa0...",
#   u'title': u'Edwin Tam | LinkedIn'},
#  {u'displayLink': u'sg.linkedin.com',
#   u'formattedUrl': u'https://sg.linkedin.com/in/edwintam',
#   u'htmlFormattedUrl': u'https://sg.linkedin.com/in/<b>edwintam</b>',
#   u'htmlSnippet': u'View <b>Edwin Tam&#39;s</b> profile on LinkedIn, the world&#39;s largest professional community<br>\n. Edwin has 11 jobs jobs listed on their profile. See the complete profile on&nbsp;...',
#   u'htmlTitle': u'<b>Edwin Tam</b> - Digital Strategy Director - Construct Digital | LinkedIn',
#   u'kind': u'customsearch#result',
#   u'link': u'https://sg.linkedin.com/in/edwintam',
#   u'pagemap': {u'cse_image': [{u'src': u'https://media.licdn.com/dms/image/C4E03AQFHm0ZHed3Zag/profile-displayphoto-shrink_200_200/0?e=1529874000&v=beta&t=D2Ol9CyA7FZQCthHvKFc_Hf7O299WvGPphSTvRM52tQ'}],
#                u'cse_thumbnail': [{u'height': u'200',
#                                    u'src': u'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSogqkuMmoTf1Vl6P3oXecY3SPEXt4UVApEcgBvOGTjpfEtdDqCRIfBcs4',
#                                    u'width': u'200'}],
#                u'hcard': [{u'fn': u'Edwin Tam',
#                            u'title': u'Strategist (Digital & Data)'}],
#                u'metatags': [{u'apphost': u'public-profile-frontend',
#                               u'appinstance': u'i001',
#                               u'application-name': u'LinkedIn',
#                               u'appname': u'chrome',
#                               u'appversion': u'0.1.446',
#                               u'detectadblock': u'//platform.linkedin.com/js/px.js',
#                               u'globaltrackingappid': u'webTracking',
#                               u'globaltrackingappname': u'chrome',
#                               u'globaltrackingurl': u'//www.linkedin.com/mob/tracking',
#                               u'lnkd-track-json-lib': u'https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv',
#                               u'msapplication-tilecolor': u'#0077B5',
#                               u'msapplication-tileimage': u'https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png',
#                               u'og:description': u"View Edwin Tam\u2019s profile on LinkedIn, the world's largest professional community. Edwin has 11 jobs jobs listed on their profile. See the complete profile on LinkedIn and discover Edwin\u2019s connections and jobs at similar companies.",
#                               u'og:image': u'https://media.licdn.com/dms/image/C4E03AQFHm0ZHed3Zag/profile-displayphoto-shrink_200_200/0?e=1529874000&v=beta&t=D2Ol9CyA7FZQCthHvKFc_Hf7O299WvGPphSTvRM52tQ',
#                               u'og:title': u'Edwin Tam - Digital Strategy Director - Construct Digital | LinkedIn',
#                               u'og:url': u'https://sg.linkedin.com/in/edwintam?trk=public_profile_card_url',
#                               u'pageimpressionid': u'2a223cbb-093d-4926-be6b-34319f95d5fb',
#                               u'pagekey': u'public_profile_v3_desktop',
#                               u'referrer': u'origin',
#                               u'remotenavjscontentbaseurl': u'https://static.licdn.com/scds/concat/common/js?v=0.1.509',
#                               u'treeid': u'D0EmmnjIKBUw44ZflysAAA==',
#                               u'twitter:card': u'summary',
#                               u'twitter:site': u'@LinkedIn'}],
#                u'person': [{u'org': u'Construct Digital',
#                             u'role': u'Strategist (Digital & Data)'}]},
#   u'snippet': u"View Edwin Tam's profile on LinkedIn, the world's largest professional community\n. Edwin has 11 jobs jobs listed on their profile. See the complete profile on\xa0...",
#   u'title': u'Edwin Tam - Digital Strategy Director - Construct Digital | LinkedIn'},
#  {u'cacheId': u'RNkRqH09wBUJ',
#   u'displayLink': u'www.facebook.com',
#   u'formattedUrl': u'https://www.facebook.com/public/Edwin-Tam',
#   u'htmlFormattedUrl': u'https://www.facebook.com/public/<b>Edwin</b>-<b>Tam</b>',
#   u'htmlSnippet': u'View the profiles of people named <b>Edwin Tam</b>. Join Facebook to connect with <br>\n<b>Edwin Tam</b> and others you may know. Facebook gives people the power to share<br>\n.',
#   u'htmlTitle': u'<b>Edwin Tam</b> Profiles | Facebook',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.facebook.com/public/Edwin-Tam',
#   u'pagemap': {u'metatags': [{u'referrer': u'default'}]},
#   u'snippet': u'View the profiles of people named Edwin Tam. Join Facebook to connect with \nEdwin Tam and others you may know. Facebook gives people the power to share\n.',
#   u'title': u'Edwin Tam Profiles | Facebook'},
#  {u'cacheId': u'9xJsm03T-gkJ',
#   u'displayLink': u'www.centralhealth.com.hk',
#   u'formattedUrl': u'https://www.centralhealth.com.hk/who-we-are/16/2',
#   u'htmlFormattedUrl': u'https://www.centralhealth.com.hk/who-we-are/16/2',
#   u'htmlSnippet': u'Dr <b>Edwin Tam</b>. MB BS, BSc (Med), Grad Dip Med (Clin. Epi), FRANZCOG, DDU. <br>\ndretam@centralhealth.com.hk. Dr Christina Hui. Specialist in Obstetrics &amp;&nbsp;...',
#   u'htmlTitle': u'Obstetrics &amp; Gynaecology',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.centralhealth.com.hk/who-we-are/16/2',
#   u'pagemap': {u'cse_image': [{u'src': u'https://www.centralhealth.com.hk/sites/default/files/styles/image_focus/public/Lucy%20Lord%20biography%20-%2015%20March%202012.jpg?itok=ot8VaxyZ'}],
#                u'cse_thumbnail': [{u'height': u'100',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQGV3Ka-AhFk-NOhP0ObqapK01QpmhBjrtIy406_KCkyvsxvSD8SOs',
#                                    u'width': u'100'}],
#                u'metatags': [{u'handheldfriendly': u'true',
#                               u'mobileoptimized': u'width',
#                               u'viewport': u'width=device-width'}]},
#   u'snippet': u'Dr Edwin Tam. MB BS, BSc (Med), Grad Dip Med (Clin. Epi), FRANZCOG, DDU. \ndretam@centralhealth.com.hk. Dr Christina Hui. Specialist in Obstetrics &\xa0...',
#   u'title': u'Obstetrics & Gynaecology'},
#  {u'displayLink': u'ca.linkedin.com',
#   u'formattedUrl': u'https://ca.linkedin.com/in/edwin-tam-ba03436',
#   u'htmlFormattedUrl': u'https://ca.linkedin.com/in/<b>edwin</b>-<b>tam</b>-ba03436',
#   u'htmlSnippet': u'View <b>Edwin Tam&#39;s</b> profile on LinkedIn, the world&#39;s largest professional community<br>\n. Edwin has 2 jobs jobs listed on their profile. See the complete profile on&nbsp;...',
#   u'htmlTitle': u'<b>Edwin Tam</b> - Assistant Dean, Student Affairs, Faculty of Engineering ...',
#   u'kind': u'customsearch#result',
#   u'link': u'https://ca.linkedin.com/in/edwin-tam-ba03436',
#   u'pagemap': {u'cse_image': [{u'src': u'https://static.licdn.com/scds/common/u/images/themes/katy/ghosts/person/ghost_person_200x200_v1.png'}],
#                u'cse_thumbnail': [{u'height': u'200',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQcPzunhfeZGpwAgK3pyJ_QoXImtE6-ZqA5dNniI6Y6T-xgofmzKg02be8j',
#                                    u'width': u'200'}],
#                u'hcard': [{u'fn': u'Edwin Tam',
#                            u'photo': u'https://static.licdn.com/scds/common/u/images/themes/katy/ghosts/person/ghost_person_200x200_v1.png',
#                            u'title': u'Assistant Dean, Faculty of Engineering at University of Windsor'}],
#                u'metatags': [{u'apphost': u'public-profile-frontend',
#                               u'appinstance': u'i001',
#                               u'application-name': u'LinkedIn',
#                               u'appname': u'chrome',
#                               u'appversion': u'0.1.439',
#                               u'detectadblock': u'//platform.linkedin.com/js/px.js',
#                               u'globaltrackingappid': u'webTracking',
#                               u'globaltrackingappname': u'chrome',
#                               u'globaltrackingurl': u'//www.linkedin.com/mob/tracking',
#                               u'lnkd-track-json-lib': u'https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv',
#                               u'msapplication-tilecolor': u'#0077B5',
#                               u'msapplication-tileimage': u'https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png',
#                               u'og:description': u"View Edwin Tam\u2019s profile on LinkedIn, the world's largest professional community. Edwin has 2 jobs jobs listed on their profile. See the complete profile on LinkedIn and discover Edwin\u2019s connections and jobs at similar companies.",
#                               u'og:image': u'https://static.licdn.com/scds/common/u/images/themes/katy/ghosts/person/ghost_person_200x200_v1.png',
#                               u'og:title': u'Edwin Tam - Assistant Dean, Student Affairs, Faculty of Engineering - University of Windsor | LinkedIn',
#                               u'og:url': u'https://ca.linkedin.com/in/edwin-tam-ba03436?trk=public_profile_card_url',
#                               u'pageimpressionid': u'0bb432ac-8c22-422c-938b-54b2a1d79c4d',
#                               u'pagekey': u'public_profile_v3_desktop',
#                               u'referrer': u'origin',
#                               u'remotenavjscontentbaseurl': u'https://static.licdn.com/scds/concat/common/js?v=0.1.508',
#                               u'treeid': u'uG+WWd7PJBWwn9s3/SoAAA==',
#                               u'twitter:card': u'summary',
#                               u'twitter:site': u'@LinkedIn'}],
#                u'person': [{u'org': u'University of Windsor',
#                             u'role': u'Assistant Dean, Faculty of Engineering at University of Windsor'}]},
#   u'snippet': u"View Edwin Tam's profile on LinkedIn, the world's largest professional community\n. Edwin has 2 jobs jobs listed on their profile. See the complete profile on\xa0...",
#   u'title': u'Edwin Tam - Assistant Dean, Student Affairs, Faculty of Engineering ...'},
#  {u'cacheId': u'hndMeKAZdZwJ',
#   u'displayLink': u'www.centralhealth.com.hk',
#   u'formattedUrl': u'https://www.centralhealth.com.hk/.../doctors-away-dr-edwin-tam-218-221- and-dr-lucy-lord-218-31',
#   u'htmlFormattedUrl': u'https://www.centralhealth.com.hk/.../doctors-away-dr-<b>edwin</b>-<b>tam</b>-218-221- and-dr-lucy-lord-218-31',
#   u'htmlSnippet': u'Feb 17, 2017 <b>...</b> Please be informed that: Dr <b>Edwin Tam</b> will be away from February 18 to <br>\nFebruary 21. Dr Lucy Lord will be away from February 18 to March 1.',
#   u'htmlTitle': u'Dr <b>Edwin Tam</b>',
#   u'kind': u'customsearch#result',
#   u'link': u'https://www.centralhealth.com.hk/content/doctors-away-dr-edwin-tam-218-221-and-dr-lucy-lord-218-31',
#   u'pagemap': {u'Item': [{u'created': u'2017-02-17T17:11:26+08:00',
#                           u'date': u'2017-02-17T17:11:26+08:00',
#                           u'encoded': u'Please be informed that: Dr Edwin Tam will be away from February 18 to February 21. Dr Lucy Lord will be away from February 18 to March 1. _________________________________________________________...',
#                           u'title': u'Doctors Away - Dr Edwin Tam (2/18 - 2/21) and Dr Lucy Lord (2/18 - 3/1)'}],
#                u'metatags': [{u'handheldfriendly': u'true',
#                               u'mobileoptimized': u'width',
#                               u'viewport': u'width=device-width'}]},
#   u'snippet': u'Feb 17, 2017 ... Please be informed that: Dr Edwin Tam will be away from February 18 to \nFebruary 21. Dr Lucy Lord will be away from February 18 to March 1.',
#   u'title': u'Dr Edwin Tam'},
#  {u'cacheId': u'sSQBLWerpzUJ',
#   u'displayLink': u'maelstromcore.com',
#   u'formattedUrl': u'maelstromcore.com/?page_id=384',
#   u'htmlFormattedUrl': u'maelstromcore.com/?page_id=384',
#   u'htmlSnippet': u'<b>Edwin Tam</b> \u2013 Master Instructor | Training in the Weapon Arts of Southeast Asia.',
#   u'htmlTitle': u'<b>Edwin Tam</b> \u2013 Master Instructor | maelstr\xf8m',
#   u'kind': u'customsearch#result',
#   u'link': u'http://maelstromcore.com/?page_id=384',
#   u'pagemap': {u'cse_image': [{u'src': u'http://maelstromcore.com/sandbox/wp-content/uploads/2013/01/edwin_01_crop_1200k.jpg'}],
#                u'cse_thumbnail': [{u'height': u'178',
#                                    u'src': u'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcR2mYDqydLjU-U-pKsx9UnxRwakwVgjU9ijBHMSbSjf5RIjCpmmGmGTl5uP',
#                                    u'width': u'283'}],
#                u'metatags': [{u'fb:app_id': u'261323564048103',
#                               u'og:description': u'Mandala Mandatus\xa0\xa0Edwin Tam - Pekiti-Tirsia System of Kali Other information',
#                               u'og:image': u'http://maelstromcore.com/sandbox/wp-content/uploads/2013/01/edwin_01_crop_1200k.jpg',
#                               u'og:locale': u'en_US',
#                               u'og:site_name': u'maelstr\xf8m',
#                               u'og:title': u'Edwin Tam \u2013 Master Instructor',
#                               u'og:type': u'article',
#                               u'og:url': u'http://maelstromcore.com/?page_id=384',
#                               u'viewport': u'width=device-width,minimum-scale=1,maximum-scale=1'}]},
#   u'snippet': u'Edwin Tam \u2013 Master Instructor | Training in the Weapon Arts of Southeast Asia.',
#   u'title': u'Edwin Tam \u2013 Master Instructor | maelstr\xf8m'}]

# %%
# Prepare an array to pass the relevant links to a Pandas dataframe
for_df = []

# Filter only LinkedIn results
for name in range(len(results)) :
    for hits in range(len(results[name])) :
        if "linkedin.com" in results[name][hits]["link"] :
            for_df.append(results[name][hits])
            
df = pd.DataFrame(for_df)

# %%
# Only displayLink, link, htmlSnippet, htmlTitle, snippet are useful for export, so let's isolate
df_export = df.loc[:, ["displayLink", "link", "htmlSnippet", "htmlTitle", "snippet"]]
df_export
# Out:
#         displayLink                                           link  \
# 0  www.linkedin.com           https://www.linkedin.com/in/guangyic
# 1  www.linkedin.com  https://www.linkedin.com/in/edwin-tam-6b653a2
# 2   sg.linkedin.com            https://sg.linkedin.com/in/edwintam
# 3   ca.linkedin.com   https://ca.linkedin.com/in/edwin-tam-ba03436
#
#                                          htmlSnippet  \
# 0  Se <b>Guang Yi</b> Chuas profil på LinkedIn – ...
# 1  View <b>Edwin Tam&#39;s</b> professional profi...
# 2  View <b>Edwin Tam&#39;s</b> profile on LinkedI...
# 3  View <b>Edwin Tam&#39;s</b> profile on LinkedI...
#
#                                            htmlTitle  \
# 0               <b>Guang Yi Chua</b> | Faglig profil
# 1                        <b>Edwin Tam</b> | LinkedIn
# 2  <b>Edwin Tam</b> - Digital Strategy Director -...
# 3  <b>Edwin Tam</b> - Assistant Dean, Student Aff...
#
#                                              snippet
# 0  Se Guang Yi Chuas profil på LinkedIn – verdens...
# 1  View Edwin Tam's professional profile on Linke...
# 2  View Edwin Tam's profile on LinkedIn, the worl...
# 3  View Edwin Tam's profile on LinkedIn, the worl...

# %% [markdown]
# #### Companies
#
# Search is not limited to just people. Finding out company information for B2B is just as powerful and useful.

# %%
company_search = ["Construct Digital", "Google"]
results2 = []

# Again, isolate only the LinkedIn results
for companies in company_search :
    search_string = companies + " LinkedIn"
    results2.append(google_search(search_string, my_api_key, my_cse_id, num=10))

# %%
for_df2 = []

for name in range(len(results2)) :
    for hits in range(len(results2[name])) :
        if "linkedin.com" in results2[name][hits]["link"] :
            #print "Company!"
            if "company" in results2[name][hits]["link"] :
                for_df2.append(results2[name][hits])
                #print "Company"
            
df2 = pd.DataFrame(for_df2)

# %%
df2_export = df2.loc[:, ["displayLink", "link", "htmlSnippet", "htmlTitle", "snippet"]]
df2_export
# Out:
#         displayLink                                               link  \
# 0  www.linkedin.com  https://www.linkedin.com/company/construct-dig...
# 1  www.linkedin.com            https://www.linkedin.com/company/google
# 2   sg.linkedin.com             https://sg.linkedin.com/company/google
# 3  www.linkedin.com       https://www.linkedin.com/company/google/jobs
# 4   au.linkedin.com             https://au.linkedin.com/company/google
# 5   ca.linkedin.com             https://ca.linkedin.com/company/google
# 6   il.linkedin.com             https://il.linkedin.com/company/google
#
#                                          htmlSnippet  \
# 0  Learn about working at <b>Construct Digital</b...
# 1  Learn about working at <b>Google</b>. Join <b>...
# 2  Learn about working at <b>Google</b>. Join <b>...
# 3  Learn about working at <b>Google</b>. Join <b>...
# 4  Learn about working at <b>Google</b>. Join <b>...
# 5  Learn about working at <b>Google</b>. Join <b>...
# 6  Learn about working at <b>Google</b>. Join <b>...
#
#                                     htmlTitle  \
# 0  <b>Construct Digital</b> | <b>LinkedIn</b>
# 1             <b>Google</b> | <b>LinkedIn</b>
# 2             <b>Google</b> | <b>LinkedIn</b>
# 3       <b>Google</b>: Jobs | <b>LinkedIn</b>
# 4             <b>Google</b> | <b>LinkedIn</b>
# 5             <b>Google</b> | <b>LinkedIn</b>
# 6             <b>Google</b> | <b>LinkedIn</b>
#
#                                              snippet
# 0  Learn about working at Construct Digital. Join...
# 1  Learn about working at Google. Join LinkedIn t...
# 2  Learn about working at Google. Join LinkedIn t...
# 3  Learn about working at Google. Join LinkedIn t...
# 4  Learn about working at Google. Join LinkedIn t...
# 5  Learn about working at Google. Join LinkedIn t...
# 6  Learn about working at Google. Join LinkedIn t...

# %% [markdown]
# When finished, export in your favorite format.
